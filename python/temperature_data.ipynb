# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 자료출처
#  - 지역별 수온온도 : 기상청(https://data.kma.go.kr/data/sea/selectBuoyRltmList.do?pgmNo=52)

# %%
shinan_df=pd.read_csv('./data/temperature/신안 통합.csv',encoding='cp949',index_col='일시')
df1=shinan_df.iloc[:,1:].groupby('일시').mean()
df1['지점']=22183
df1.to_csv('./data/temperature/month/신안_월별.csv',encoding='cp949')

# %%
geomun_df=pd.read_csv('./data/temperature/거문도 통합.csv',encoding='cp949',index_col='일시')
df2=geoje_df.iloc[:,1:].groupby('일시').mean()
df2['지점']=22103
df2.to_csv('./data/temperature/month/거문도_월별.csv',encoding='cp949')

# %%
geoje_df=pd.read_csv('./data/temperature/거제도 통합.csv',encoding='cp949',index_col='일시')
df3=geoje_df.iloc[:,1:].groupby('일시').mean()
df3['지점']=22104
df3.to_csv('./data/temperature/month/거제도_월별.csv',encoding='cp949')

# %%
ulsan_df=pd.read_csv('./data/temperature/울산 통합.csv',encoding='cp949')
df4=ulsan_df.iloc[:,1:].groupby('일시').mean()
df4['지점']=22189
df4.to_csv('./data/temperature/month/울산_월별.csv',encoding='cp949')

# %%
ulsan_df=pd.read_csv('./data/temperature/추자도 통합.csv',encoding='cp949')
df4=ulsan_df.iloc[:,1:].groupby('일시').mean()
df4['지점']=22184
df4.to_csv('./data/temperature/month/울산_월별.csv',encoding='cp949')

# %%
df1.corr()
# Out:
#              평균 풍속(m/s)  평균기압(hPa)  평균 상대습도(%)  평균 기온(°C)  평균 수온(°C)  \
# 평균 풍속(m/s)     1.000000   0.859587   -0.794749  -0.767319  -0.658459
# 평균기압(hPa)      0.859587   1.000000   -0.888791  -0.892999  -0.792991
# 평균 상대습도(%)    -0.794749  -0.888791    1.000000   0.774605   0.663610
# 평균 기온(°C)     -0.767319  -0.892999    0.774605   1.000000   0.972685
# 평균 수온(°C)     -0.658459  -0.792991    0.663610   0.972685   1.000000
# 평균 최대 파고(m)    0.856453   0.785051   -0.783351  -0.716993  -0.590045
# 평균 유의 파고(m)    0.860826   0.847756   -0.743378  -0.749145  -0.633237
# 최고 유의 파고(m)    0.894204   0.890034   -0.815028  -0.793323  -0.672309
# 최고 최대 파고(m)    0.790978   0.747366   -0.719091  -0.645654  -0.518094
# 평균 파주기(sec)   -0.052846  -0.052048   -0.078998  -0.020953  -0.044951
# 최고 파주기(sec)   -0.012618  -0.027577   -0.127190  -0.040283  -0.043494
# 지점                  NaN        NaN         NaN        NaN        NaN
#
# ...

# %%
df2.corr()
# Out:
#              평균 풍속(m/s)  평균기압(hPa)  평균 상대습도(%)  평균 기온(°C)  평균 수온(°C)  \
# 평균 풍속(m/s)     1.000000   0.711025   -0.558340  -0.606831  -0.422434
# 평균기압(hPa)      0.711025   1.000000   -0.695306  -0.783227  -0.613100
# 평균 상대습도(%)    -0.558340  -0.695306    1.000000   0.677654   0.466099
# 평균 기온(°C)     -0.606831  -0.783227    0.677654   1.000000   0.909417
# 평균 수온(°C)     -0.422434  -0.613100    0.466099   0.909417   1.000000
# 평균 최대 파고(m)    0.340558  -0.064246    0.056178   0.034083   0.114587
# 평균 유의 파고(m)    0.189446  -0.063418    0.066846   0.008270   0.032647
# 최고 유의 파고(m)    0.220389  -0.043076    0.041422  -0.020637  -0.000948
# 최고 최대 파고(m)    0.360417  -0.019350   -0.010745  -0.029451   0.043160
# 평균 파주기(sec)    0.080307   0.058186   -0.101273   0.038929   0.126457
# 최고 파주기(sec)    0.115870   0.127891   -0.156205  -0.088121  -0.017436
# 지점                  NaN        NaN         NaN        NaN        NaN
#
# ...

# %%
df3.corr()
# Out:
#              평균 풍속(m/s)  평균기압(hPa)  평균 상대습도(%)  평균 기온(°C)  평균 수온(°C)  \
# 평균 풍속(m/s)     1.000000   0.460749   -0.448086  -0.341107  -0.188440
# 평균기압(hPa)      0.460749   1.000000   -0.903674  -0.831105  -0.586339
# 평균 상대습도(%)    -0.448086  -0.903674    1.000000   0.801270   0.536902
# 평균 기온(°C)     -0.341107  -0.831105    0.801270   1.000000   0.869319
# 평균 수온(°C)     -0.188440  -0.586339    0.536902   0.869319   1.000000
# 평균 최대 파고(m)    0.730477   0.113213   -0.092172   0.006280   0.080005
# 평균 유의 파고(m)    0.355379   0.104105   -0.107468   0.031510   0.117687
# 최고 유의 파고(m)    0.337180   0.100084   -0.118241   0.027277   0.092972
# 최고 최대 파고(m)    0.680752   0.118528   -0.113294  -0.013455   0.034216
# 평균 파주기(sec)    0.064631  -0.121021    0.157277   0.090510   0.030186
# 최고 파주기(sec)    0.088317  -0.070839    0.125456   0.022603  -0.043179
# 지점                  NaN        NaN         NaN        NaN        NaN
#
# ...

# %%
df4.corr()
# Out:
#              평균 풍속(m/s)  평균기압(hPa)  평균 상대습도(%)  평균 기온(°C)  평균 수온(°C)  \
# 평균 풍속(m/s)     1.000000   0.473623   -0.397007  -0.467204  -0.382213
# 평균기압(hPa)      0.473623   1.000000   -0.911193  -0.838055  -0.645527
# 평균 상대습도(%)    -0.397007  -0.911193    1.000000   0.813864   0.619075
# 평균 기온(°C)     -0.467204  -0.838055    0.813864   1.000000   0.899463
# 평균 수온(°C)     -0.382213  -0.645527    0.619075   0.899463   1.000000
# 평균 최대 파고(m)    0.771229   0.649567   -0.570774  -0.561647  -0.382455
# 평균 유의 파고(m)    0.775048   0.634824   -0.548719  -0.546688  -0.368080
# 최고 유의 파고(m)    0.769734   0.617916   -0.529975  -0.525748  -0.380185
# 최고 최대 파고(m)    0.753249   0.636514   -0.547749  -0.543118  -0.391324
# 평균 파주기(sec)    0.323226   0.521557   -0.523700  -0.382429  -0.252612
# 최고 파주기(sec)    0.181890   0.367717   -0.325874  -0.218121  -0.148910
# 지점                  NaN        NaN         NaN        NaN        NaN
#
# ...
